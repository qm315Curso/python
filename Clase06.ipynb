# %% [markdown]
# <a href="https://colab.research.google.com/github/qm315Curso/python/blob/main/Clase06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = {
    "id":           [1, 2, 3, 4, 5, 6, 7, 8],
    "nombre":       ["Ana", "Luis", "María", "Carlos",
                     "Rosa", "Pedro", "Elena", "Jorge"],
    "facultad":     ["Ciencias", "Ingeniería", "Ciencias", "Humanidades",
                     "Ingeniería", "Ciencias", "Humanidades", "Ingeniería"],
    "publicaciones":[12, 8, 20, 5, 15, 3, 9, 18],
    "h_index":      [7, 4, 11, 3, 8, 2, 5, 10],
    "financiamiento":[45000, 28000, 72000, None, 55000,
                      12000, None, 63000],
    "anio_ingreso": [2015, 2018, 2012, 2020, 2016, 2021, 2019, 2014],
    "activo":       [True, True, True, False, True, True, True, True]
}

df = pd.DataFrame(data)
df.to_csv("output.csv",index=False)

# %%
url="https://raw.githubusercontent.com/qm315Curso/python/refs/heads/main/output.csv"
df=pd.read_csv(url)
df
# Out:
#    id  nombre     facultad  publicaciones  h_index  financiamiento  \
# 0   1     Ana     Ciencias             12        7           45000
# 1   2    Luis   Ingenieria              8        4           28000
# 2   3   Maria     Ciencias             20       11           72000
# 3   4  Carlos  Humanidades              5        3               0
# 4   5    Rosa  Ingenieriia             15        8           55000
# 5   6   Pedro     Ciencias              3        2           12000
# 6   7   Elena  Humanidades              9        5               0
# 7   8   Jorge   Ingenieria             18       10           63000
#
#    anio_ingreso  activo
# 0          2015    True
# 1          2018    True
# 2          2012    True
# 3          2020   False
# 4          2016    True
# 5          2021    True
# 6          2019    True
# 7          2014    True

# %%
print(df.shape[1])
print(df.dtypes)
# Out:
# 8
# id                 int64
# nombre            object
# facultad          object
# publicaciones      int64
# h_index            int64
# financiamiento     int64
# anio_ingreso       int64
# activo              bool
# dtype: object

# %%
df[["nombre","facultad","publicaciones"]]
# Out:
#    nombre     facultad  publicaciones
# 0     Ana     Ciencias             12
# 1    Luis   Ingenieria              8
# 2   Maria     Ciencias             20
# 3  Carlos  Humanidades              5
# 4    Rosa  Ingenieriia             15
# 5   Pedro     Ciencias              3
# 6   Elena  Humanidades              9
# 7   Jorge   Ingenieria             18

# %%
columnas=["activo","nombre","id"]
df[columnas]
# Out:
#    activo  nombre  id
# 0    True     Ana   1
# 1    True    Luis   2
# 2    True   Maria   3
# 3   False  Carlos   4
# 4    True    Rosa   5
# 5    True   Pedro   6
# 6    True   Elena   7
# 7    True   Jorge   8

# %%
df.iloc[0:5,1:4]
# Out:
#    nombre     facultad  publicaciones
# 0     Ana     Ciencias             12
# 1    Luis   Ingenieria              8
# 2   Maria     Ciencias             20
# 3  Carlos  Humanidades              5
# 4    Rosa  Ingenieriia             15

# %%
df.iloc[3:8,:]
# Out:
#    id  nombre     facultad  publicaciones  h_index  financiamiento  \
# 3   4  Carlos  Humanidades              5        3               0
# 4   5    Rosa  Ingenieriia             15        8           55000
# 5   6   Pedro     Ciencias              3        2           12000
# 6   7   Elena  Humanidades              9        5               0
# 7   8   Jorge   Ingenieria             18       10           63000
#
#    anio_ingreso  activo
# 3          2020   False
# 4          2016    True
# 5          2021    True
# 6          2019    True
# 7          2014    True

# %%
df.query("facultad == 'Ciencias'")
# Out:
#    id nombre  facultad  publicaciones  h_index  financiamiento  anio_ingreso  \
# 0   1    Ana  Ciencias             12        7           45000          2015
# 2   3  Maria  Ciencias             20       11           72000          2012
# 5   6  Pedro  Ciencias              3        2           12000          2021
#
#    activo
# 0    True
# 2    True
# 5    True

# %%
df.query("activo==True")
# Out:
#    id nombre     facultad  publicaciones  h_index  financiamiento  \
# 0   1    Ana     Ciencias             12        7           45000
# 1   2   Luis   Ingenieria              8        4           28000
# 2   3  Maria     Ciencias             20       11           72000
# 4   5   Rosa  Ingenieriia             15        8           55000
# 5   6  Pedro     Ciencias              3        2           12000
# 6   7  Elena  Humanidades              9        5               0
# 7   8  Jorge   Ingenieria             18       10           63000
#
#    anio_ingreso  activo
# 0          2015    True
# 1          2018    True
# 2          2012    True
# 4          2016    True
# 5          2021    True
# 6          2019    True
# 7          2014    True

# %%
df.query("publicaciones>5 and publicaciones<15")
# Out:
#    id nombre     facultad  publicaciones  h_index  financiamiento  \
# 0   1    Ana     Ciencias             12        7           45000
# 1   2   Luis   Ingenieria              8        4           28000
# 6   7  Elena  Humanidades              9        5               0
#
#    anio_ingreso  activo
# 0          2015    True
# 1          2018    True
# 6          2019    True

# %%
df.query("facultad=='Humanidades' and anio_ingreso==2019")
# Out:
#    id nombre     facultad  publicaciones  h_index  financiamiento  \
# 6   7  Elena  Humanidades              9        5               0
#
#    anio_ingreso  activo
# 6          2019    True

# %%
df.query("facultad not in ['Humanidades']")
# Out:
#    id nombre     facultad  publicaciones  h_index  financiamiento  \
# 0   1    Ana     Ciencias             12        7           45000
# 1   2   Luis   Ingenieria              8        4           28000
# 2   3  Maria     Ciencias             20       11           72000
# 4   5   Rosa  Ingenieriia             15        8           55000
# 5   6  Pedro     Ciencias              3        2           12000
# 7   8  Jorge   Ingenieria             18       10           63000
#
#    anio_ingreso  activo
# 0          2015    True
# 1          2018    True
# 2          2012    True
# 4          2016    True
# 5          2021    True
# 7          2014    True

# %%
facultades_stem = ["Ciencias", "Ingenieria"]
df.query("facultad in @facultades_stem")
# Out:
#    id nombre    facultad  publicaciones  h_index  financiamiento  \
# 0   1    Ana    Ciencias             12        7           45000
# 1   2   Luis  Ingenieria              8        4           28000
# 2   3  Maria    Ciencias             20       11           72000
# 5   6  Pedro    Ciencias              3        2           12000
# 7   8  Jorge  Ingenieria             18       10           63000
#
#    anio_ingreso  activo
# 0          2015    True
# 1          2018    True
# 2          2012    True
# 5          2021    True
# 7          2014    True

# %%
df.filter(like="ingreso")
# Out:
#    anio_ingreso
# 0          2015
# 1          2018
# 2          2012
# 3          2020
# 4          2016
# 5          2021
# 6          2019
# 7          2014

# %%
df.filter(regex="bre")
# Out:
#    nombre
# 0     Ana
# 1    Luis
# 2   Maria
# 3  Carlos
# 4    Rosa
# 5   Pedro
# 6   Elena
# 7   Jorge

# %%
df.select_dtypes(include=["object","bool"])
# Out:
#    nombre     facultad  activo
# 0     Ana     Ciencias    True
# 1    Luis   Ingenieria    True
# 2   Maria     Ciencias    True
# 3  Carlos  Humanidades   False
# 4    Rosa  Ingenieriia    True
# 5   Pedro     Ciencias    True
# 6   Elena  Humanidades    True
# 7   Jorge   Ingenieria    True

# %%
df2=df.drop(columns=["id", "activo"])
df2
# Out:
#    nombre     facultad  publicaciones  h_index  financiamiento  anio_ingreso
# 0     Ana     Ciencias             12        7           45000          2015
# 1    Luis   Ingenieria              8        4           28000          2018
# 2   Maria     Ciencias             20       11           72000          2012
# 3  Carlos  Humanidades              5        3               0          2020
# 4    Rosa  Ingenieriia             15        8           55000          2016
# 5   Pedro     Ciencias              3        2           12000          2021
# 6   Elena  Humanidades              9        5               0          2019
# 7   Jorge   Ingenieria             18       10           63000          2014

# %%
df.sort_values("publicaciones", ascending=True)
# Out:
#    id  nombre     facultad  publicaciones  h_index  financiamiento  \
# 5   6   Pedro     Ciencias              3        2           12000
# 3   4  Carlos  Humanidades              5        3               0
# 1   2    Luis   Ingenieria              8        4           28000
# 6   7   Elena  Humanidades              9        5               0
# 0   1     Ana     Ciencias             12        7           45000
# 4   5    Rosa  Ingenieriia             15        8           55000
# 7   8   Jorge   Ingenieria             18       10           63000
# 2   3   Maria     Ciencias             20       11           72000
#
#    anio_ingreso  activo
# 5          2021    True
# 3          2020   False
# 1          2018    True
# 6          2019    True
# 0          2015    True
# 4          2016    True
# 7          2014    True
# 2          2012    True

# %%
df.sort_values("h_index", ascending=False)
# Out:
#    id  nombre     facultad  publicaciones  h_index  financiamiento  \
# 2   3   Maria     Ciencias             20       11           72000
# 7   8   Jorge   Ingenieria             18       10           63000
# 4   5    Rosa  Ingenieriia             15        8           55000
# 0   1     Ana     Ciencias             12        7           45000
# 6   7   Elena  Humanidades              9        5               0
# 1   2    Luis   Ingenieria              8        4           28000
# 3   4  Carlos  Humanidades              5        3               0
# 5   6   Pedro     Ciencias              3        2           12000
#
#    anio_ingreso  activo
# 2          2012    True
# 7          2014    True
# 4          2016    True
# 0          2015    True
# 6          2019    True
# 1          2018    True
# 3          2020   False
# 5          2021    True

# %%
df.sort_values("nombre", ascending=True).sort_values("facultad",ascending=True)
# Out:
#    id  nombre     facultad  publicaciones  h_index  financiamiento  \
# 0   1     Ana     Ciencias             12        7           45000
# 2   3   Maria     Ciencias             20       11           72000
# 5   6   Pedro     Ciencias              3        2           12000
# 3   4  Carlos  Humanidades              5        3               0
# 6   7   Elena  Humanidades              9        5               0
# 7   8   Jorge   Ingenieria             18       10           63000
# 1   2    Luis   Ingenieria              8        4           28000
# 4   5    Rosa  Ingenieriia             15        8           55000
#
#    anio_ingreso  activo
# 0          2015    True
# 2          2012    True
# 5          2021    True
# 3          2020   False
# 6          2019    True
# 7          2014    True
# 1          2018    True
# 4          2016    True

# %%
df.sort_values(
    ["facultad", "nombre"],
    ascending=[True, True],
    ignore_index=True
)
# Out:
#    id  nombre     facultad  publicaciones  h_index  financiamiento  \
# 0   1     Ana     Ciencias             12        7           45000
# 1   3   Maria     Ciencias             20       11           72000
# 2   6   Pedro     Ciencias              3        2           12000
# 3   4  Carlos  Humanidades              5        3               0
# 4   7   Elena  Humanidades              9        5               0
# 5   8   Jorge   Ingenieria             18       10           63000
# 6   2    Luis   Ingenieria              8        4           28000
# 7   5    Rosa  Ingenieriia             15        8           55000
#
#    anio_ingreso  activo
# 0          2015    True
# 1          2012    True
# 2          2021    True
# 3          2020   False
# 4          2019    True
# 5          2014    True
# 6          2018    True
# 7          2016    True

# %%
proyectos = pd.DataFrame({
    "investigador_id": [1, 2, 3, 5, 8, 9],
    "proyecto": ["IA Médica", "IoT Agrícola", "Biodiversidad",
                 "Aguas Chiriquí", "Minería Datos", "Proyecto X"],
    "monto_usd": [30000, 15000, 42000, 28000, 55000, 10000]
})
proyectos.to_csv("proyectos.csv",index=False)
